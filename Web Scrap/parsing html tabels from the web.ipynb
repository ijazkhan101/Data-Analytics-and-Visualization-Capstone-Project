# %% [markdown]
# ## Collecting Data from web

# %%
import pandas as pd
from unicodedata import normalize

# %%
html_url = 'https://www.basketball-reference.com/leagues/NBA_stats_per_game.html'

# %%
tabs = pd.read_html(html_url)

# %%
len(tabs)
# Out:
# 1

# %%
nba =tabs[0]

# %%
nba.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Season                 Lg                Age
# 0                  1            2022-23                NBA               26.2
# 1                  2            2021-22                NBA               26.1
# 2                  3            2020-21                NBA               26.1
# 3                  4            2019-20                NBA               26.1
# 4                  5            2018-19                NBA               26.3
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Per Game        \
#                   Ht                 Wt                  G       MP    FG
# 0                6-7                216                590    242.1  41.5
# 1                6-6                215               1230    241.4  40.6
# 2                6-6                217               1080    241.4  41.2
# ...

# %%
nba.shape
# Out:
# (83, 32)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   (Unnamed: 0_level_0, Rk)      80 non-null     object
#  1   (Unnamed: 1_level_0, Season)  80 non-null     object
#  2   (Unnamed: 2_level_0, Lg)      80 non-null     object
#  3   (Unnamed: 3_level_0, Age)     75 non-null     object
#  4   (Unnamed: 4_level_0, Ht)      75 non-null     object
#  5   (Unnamed: 5_level_0, Wt)      75 non-null     object
#  6   (Unnamed: 6_level_0, G)       80 non-null     object
#  7   (Per Game, MP)                65 non-null     object
#  8   (Per Game, FG)                83 non-null     object
#  9   (Per Game, FGA)               83 non-null     object
#  10  (Per Game, 3P)                50 non-null     object
#  11  (Per Game, 3PA)               50 non-null     object
# ...

# %%
nba.describe()
# Out:
#        Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                        Rk             Season                 Lg
# count                  80                 80                 80
# unique                 78                 78                  3
# top                    Rk             Season                NBA
# freq                    3                  3                 74
#
#        Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                       Age                 Ht                 Wt
# count                  75                 75                 75
# unique                 18                  5                 28
# top                  26.4                6-7                205
# freq                   11                 39                 10
#
#        Unnamed: 6_level_0 Per Game                ...            Shooting  \
#                         G       MP  FG       FGA  ...       PTS       FG%
# ...
